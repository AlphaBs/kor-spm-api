# %%
from pandas import pandas as pd

df = pd.read_json("dataset-train.json")

# %%
spam = df[df["type"] == 1]

# %%
all_tokens = []
for tokens in spam["tokens"]:
    all_tokens.extend(tokens)

from collections import Counter

token_counts = Counter(all_tokens)
sorted_token_counts = token_counts.most_common()
sorted_token_counts
# Out:
# [('*', 7336),
#  (':', 2187),
#  ('/', 1599),
#  ('?', 1556),
#  ('+', 1404),
#  ('line', 1112),
#  ('.', 1075),
#  ('이', 999),
#  (',', 816),
#  ('저', 786),
#  ('보', 735),
#  ('사진', 696),
#  ('주', 671),
#  (')', 619),
#  ('-', 617),
#  ('(', 608),
#  ('있', 607),
#  ('하', 535),
#  ('~', 488),
#  ('llne', 474),
#  ('d', 452),
#  ('싶', 398),
#  ('만', 346),
#  ('나', 329),
#  ('원', 314),
#  ('드리', 295),
#  ('라인', 293),
#  ('오', 291),
#  ('!', 277),
#  ('추가', 277),
#  ('[', 260),
#  (']', 257),
#  ('살', 234),
#  ('수', 226),
#  ('cm', 226),
#  ('가능', 224),
#  ('시', 200),
#  ('l', 200),
#  ("'", 194),
#  ('집', 189),
#  ('com', 183),
#  ('가', 173),
#  ('오늘', 167),
#  ('밤', 164),
#  ('*%', 160),
#  ('같이', 157),
#  ('e', 151),
#  ('>', 150),
#  ('%', 148),
#  ('거', 148),
#  ('보내', 145),
#  ('되', 139),
#  ('kg', 138),
#  ('c', 136),
#  ('분', 132),
#  ('박', 131),
#  ('??', 130),
#  ('저녁', 129),
#  ('3', 126),
#  ('o', 123),
#  ('s', 122),
#  ('안', 120),
#  ('혼자', 119),
#  ('많', 118),
#  ('물', 116),
#  ('입', 115),
#  ('일', 112),
#  ('근처', 110),
#  ('지급', 110),
#  ('찍', 107),
#  ('너', 107),
#  ('확인', 107),
#  ('답장', 106),
#  ('시간', 104),
#  ('함께', 102),
#  ('자', 102),
#  ('한', 102),
#  ('a', 101),
#  ('h', 100),
#  ('때', 100),
#  ('가입', 99),
#  ('t', 99),
#  ('없', 99),
#  ('좋아하', 98),
#  ('좋', 95),
#  ('보이', 95),
#  ('우리', 95),
#  ('"', 94),
#  ('당신', 92),
#  ('무료', 91),
#  ('telegarm', 91),
#  ('n', 91),
#  ('*+*', 90),
#  ('신규', 89),
#  ('한국', 89),
#  ('듀', 89),
#  ('번', 88),
#  ('연락', 88),
#  ('찾', 88),
#  ('m', 87),
#  ('것', 85),
#  ('bit.ly', 85),
#  ('싱글', 85),
#  ('후', 84),
#  ('2', 84),
#  ('x', 82),
#  ('p', 81),
#  ('당', 80),
#  ('받', 79),
#  ('k', 79),
#  ('아래', 78),
#  ('샤워', 78),
#  ('g', 77),
#  ('만나', 75),
#  ('전', 74),
#  ('말', 74),
#  ('너무', 74),
#  ('5', 74),
#  ('질싸', 72),
#  ('f', 70),
#  ('사', 70),
#  ('r', 69),
#  ('빨리', 67),
#  ('y', 67),
#  ('1', 66),
#  ('<', 66),
#  ('|', 65),
#  ('않', 65),
#  ('u', 64),
#  ('전복', 64),
#  ('쿠폰', 63),
#  ('년', 62),
#  ('첫', 62),
#  ('v', 62),
#  ('채찍', 61),
#  ('10', 60),
#  ('지', 60),
#  ('월', 59),
#  ('님', 59),
#  ('질사', 59),
#  ('제', 59),
#  ('ne', 58),
#  ('w', 58),
#  ('사람', 58),
#  ('&', 57),
#  ('코드', 57),
#  ('기다리', 56),
#  ('컵', 56),
#  ('잘', 54),
#  ('중', 54),
#  ('b', 54),
#  ('오랄', 52),
#  ('telegram', 52),
#  ('더', 51),
#  ('분홍', 51),
#  ('먹', 51),
#  ('먼저', 49),
#  ('주소', 49),
#  ('텔', 49),
#  ('세', 49),
#  ('여성', 48),
#  ('등', 48),
#  ('photo', 48),
#  ('q', 47),
#  ('클라이막스', 47),
#  ('다리', 47),
#  ('????', 47),
#  ('몸', 46),
#  ('z', 46),
#  ('@', 46),
#  ('_', 46),
#  ('커닐을', 46),
#  ('아이디', 45),
#  ('다', 45),
#  ('외롭', 45),
#  ('0', 45),
#  ('급', 44),
#  ('장', 44),
#  ('번호', 44),
#  ('마음', 44),
#  ('간호사', 44),
#  ('털', 44),
#  ('t.ly', 44),
#  ('유치원', 44),
#  ('전화', 43),
#  ('ok', 43),
#  ('매일', 43),
#  ('길', 43),
#  ('문의', 42),
#  ('특별', 42),
#  ('애널', 42),
#  ('친구', 42),
#  ('하루', 42),
#  ('혜택', 41),
#  ('대학', 41),
#  ('바로', 40),
#  ('이벤트', 40),
#  ('!!', 39),
#  ('술', 39),
#  ('교사', 39),
#  ('abit.ly', 39),
#  ('=', 38),
#  ('알', 37),
#  ('저희', 37),
#  ('좀', 37),
#  ('넣', 36),
#  ('+*', 36),
#  ('ine', 36),
#  ('모델', 36),
#  ('출', 36),
#  ('^^', 36),
#  ('지금', 36),
#  ('용', 35),
#  ('섹스', 35),
#  ('벌리', 35),
#  ('지원', 35),
#  ('패티쉬', 35),
#  ('내', 35),
#  ('촛농', 35),
#  ('방', 35),
#  ('i', 34),
#  ('입금', 34),
#  ('엄청', 34),
#  ('주말', 34),
#  ('돈', 33),
#  ('j', 33),
#  ('마시', 33),
#  ('net', 33),
#  ('남자', 33),
#  ('id', 33),
#  ('대', 33),
#  ('카', 33),
#  ('진행', 33),
#  ('선물', 33),
#  ('이용', 33),
#  ('서비스', 32),
#  ('단', 32),
#  ('instagram', 32),
#  ('각종', 32),
#  ('방금', 32),
#  ('안내', 32),
#  ('^', 32),
#  ('금', 31),
#  ('소중하', 31),
#  ('안전', 31),
#  ('나오', 31),
#  ('ly', 31),
#  ('토담', 31),
#  ('위하', 31),
#  ('yy', 31),
#  ('연락처', 31),
#  ('9', 31),
#  ('영상', 31),
#  ('방문', 30),
#  ('도착', 30),
#  ('데', 30),
#  ('buly.kr', 30),
#  ('6', 30),
#  ('시작', 30),
#  ('필요', 30),
#  ('곳', 30),
#  ('오빠', 30),
#  ('옷', 29),
#  ('콩', 29),
#  ('https://ig.me/', 29),
#  ('들', 29),
#  ('..', 29),
#  ('즉시', 29),
#  ('입사', 28),
#  ('듣', 28),
#  ('회원', 28),
#  ('fw', 28),
#  ('30', 28),
#  ('바라', 28),
#  ('차', 28),
#  ('두', 28),
#  ('들어오', 28),
#  ('상담', 27),
#  ('보증', 27),
#  ('V', 27),
#  ('속옷', 27),
#  ('고객', 27),
#  ('촬영', 27),
#  ('키', 27),
#  ('감사', 26),
#  ('이번', 26),
#  ('아니', 26),
#  ('모든', 26),
#  ('많이', 26),
#  ('매', 26),
#  ('즐기', 26),
#  ('정착', 26),
#  ('새', 26),
#  ('완료', 26),
#  ('클릭', 25),
#  ('춥', 25),
#  ('어떻', 25),
#  ('하룻밤', 25),
#  ('만원', 25),
#  ('자세', 25),
#  ('없이', 25),
#  ('본인', 25),
#  ('크', 25),
#  ('출금', 25),
#  ('싸', 25),
#  ('sm', 25),
#  ('올리', 25),
#  ('공유', 24),
#  ('학생', 24),
#  ('여의사', 24),
#  ('충', 24),
#  ('xz', 24),
#  ('참여', 24),
#  ('...', 24),
#  ('못', 24),
#  ('등록', 24),
#  ('7', 24),
#  ('tel', 23),
#  ('여', 23),
#  ('사용', 23),
#  ('명', 23),
#  ('기프티콘', 23),
#  ('이름', 23),
#  ('퇴근', 23),
#  ('아침', 23),
#  ('최대', 23),
#  ('*+', 23),
#  ('씻', 23),
#  ('???', 23),
#  ('de', 22),
#  ('및', 22),
#  ('프', 22),
#  ('입장', 22),
#  ('프사', 22),
#  ('요즘', 22),
#  ('vo.la', 22),
#  ('인', 22),
#  ('준비', 22),
#  ('지원금', 22),
#  ('언제', 22),
#  ('다시', 22),
#  ('당일', 22),
#  ('우선', 22),
#  ('내일', 22),
#  ('event', 22),
#  ('리', 22),
#  ('즐겁', 22),
#  ('꽂', 21),
#  ('매주', 21),
#  ('발', 21),
#  ('링크', 21),
#  ('부드럽', 21),
#  ('여신', 21),
#  ('new', 21),
#  ('포인트', 21),
#  ('그', 21),
#  ('금방', 21),
#  ('no', 21),
#  ('잡', 21),
#  ('안녕하세요', 21),
#  ('이상', 21),
#  ('일단', 21),
#  ('나누', 20),
#  ('새롭', 20),
#  ('요가', 20),
#  ('같', 20),
#  ('이쁘', 20),
#  ('해제', 20),
#  ('속', 20),
#  ('누르', 20),
#  ('예', 20),
#  ('당첨', 20),
#  ('아린', 20),
#  ('어디', 20),
#  ('17.', 20),
#  ('kro.kr', 20),
#  ('과', 20),
#  ('유학', 20),
#  ('펠라치오', 20),
#  ('밑', 20),
#  ('울산', 20),
#  ('cc', 20),
#  ('누구', 20),
#  ('꼽', 20),
#  ('상품', 20),
#  ('빠르', 19),
#  ('상', 19),
#  ('선생', 19),
#  ('재', 19),
#  ('억', 19),
#  ('담당', 19),
#  ('비밀', 19),
#  ('작성', 19),
#  ('slot', 19),
#  ('ㅇ', 19),
#  ('돌발', 19),
#  ('딜', 19),
#  ('talk', 19),
#  ('예쁘', 18),
#  ('자기', 18),
#  ('조합', 18),
#  ('일본', 18),
#  ('O', 18),
#  ('비밀번호', 18),
#  ('설정', 18),
#  ('원하', 18),
#  ('보세', 18),
#  ('남편', 18),
#  ('달', 18),
#  ('문', 18),
#  ('날', 18),
#  ('개', 18),
#  ('직접', 18),
#  ('100', 18),
#  ('쓰리', 18),
#  ('섬', 18),
#  ('연', 18),
#  ('kr', 18),
#  ('뭐', 18),
#  ('젖', 18),
#  ('담당자', 18),
#  ('tele', 18),
#  ('핥', 18),
#  ('고추', 18),
#  ('활어과', 18),
#  ('ldo', 18),
#  ('처녀막', 18),
#  ('1.000.000', 18),
#  ('이거', 17),
#  ('문자', 17),
#  ('호텔', 17),
#  ('여기', 17),
#  ('코', 17),
#  ('ㅣ', 17),
#  ('드', 17),
#  ('생각', 17),
#  ('선착순', 17),
#  ('종목', 17),
#  ('경험', 17),
#  ('입싸', 17),
#  ('안녕', 17),
#  ('한번', 17),
#  ('위', 17),
#  ('최고', 17),
#  ('https://bit.ly/', 17),
#  ('도움', 17),
#  ('수익', 17),
#  ('회', 17),
#  ('lien', 17),
#  ('접속', 17),
#  ('노', 17),
#  ('음부', 17),
#  ('놀', 17),
#  ('20', 17),
#  ('백', 17),
#  ('비', 16),
#  ('ㄷ', 16),
#  ('몇', 16),
#  ('결정', 16),
#  ('비제이', 16),
#  ('관리', 16),
#  ('신', 16),
#  ('행복', 16),
#  ('실장', 16),
#  ('레', 16),
#  ('단돈', 16),
#  ('스', 16),
#  ('터', 16),
#  ('oo', 16),
#  ('목욕', 16),
#  ('lrl.kr', 16),
#  ('한정', 16),
#  ('존', 16),
#  ('원나잇', 16),
#  ('!!!', 16),
#  ('?????', 16),
#  ('강남', 16),
#  ('야외', 16),
#  ('프리', 16),
#  ('먄', 16),
#  ('배', 16),
#  ('승', 16),
#  ('we', 16),
#  ('여자', 16),
#  ('크리스마스', 16),
#  ('30,000', 16),
#  ('서두르', 16),
#  ('남', 16),
#  ('꼭', 15),
#  ('강사', 15),
#  ('사장', 15),
#  ('쓰', 15),
#  ('믿', 15),
#  ('15', 15),
#  ('만들', 15),
#  ('여교사', 15),
#  ('발송', 15),
#  ('cf', 15),
#  ('다현', 15),
#  ('열', 15),
#  ('입력', 15),
#  ('불', 15),
#  ('뒤', 15),
#  ('잊', 15),
#  ('???.', 15),
#  ('스튜어디스', 15),
#  ('이동', 15),
#  ('만남', 15),
#  ('행사', 15),
#  ('증정', 15),
#  ('연말', 15),
#  ('적용', 15),
#  ('금액', 15),
#  ('얼굴', 15),
#  ('vip', 15),
#  ('헬스', 15),
#  ('ka', 15),
#  ('생활', 15),
#  ('azi', 15),
#  ('이사비', 15),
#  ('db', 14),
#  ('놓치', 14),
#  ('개인', 14),
#  ('카톡', 14),
#  ('link', 14),
#  ('don', 14),
#  ('it.', 14),
#  ('예고', 14),
#  ('몸매', 14),
#  ('승인', 14),
#  ('사고', 14),
#  ('적', 14),
#  ('정보', 14),
#  ('yc', 14),
#  ('ㅈ', 14),
#  ('50,000', 14),
#  ('행', 14),
#  ('다양', 14),
#  ('무용', 14),
#  ('url.kr', 14),
#  ('쓰리썸', 14),
#  ('거주', 14),
#  ('ln.run', 14),
#  ('질', 14),
#  ('메세지', 14),
#  ('충전', 14),
#  ('kk', 14),
#  ('부탁', 14),
#  ('sk', 14),
#  ('타입', 14),
#  ('qu', 14),
#  ('유흥', 14),
#  ('오픈', 14),
#  ('계시', 14),
#  ('챙기', 13),
#  ('share', 13),
#  ('한림', 13),
#  ('사항', 13),
#  ('얼른', 13),
#  ('알몸', 13),
#  ('ㄹ', 13),
#  ('동거', 13),
#  ('변경', 13),
#  ('힘', 13),
#  ('클럽', 13),
#  ('초희', 13),
#  ('분수', 13),
#  ('짜릿하', 13),
#  ('얼싸', 13),
#  ('아직', 13),
#  ('ee', 13),
#  ('화장실', 13),
#  ('행운', 13),
#  ('ty', 13),
#  ('계열', 13),
#  ('쿨', 13),
#  ('요', 13),
#  ('한잔', 13),
#  ('톌', 13),
#  ('폰', 13),
#  ('sd', 13),
#  ('ㅂ', 13),
#  ('to', 13),
#  ('넘치', 13),
#  ('벌', 13),
#  ('*%*', 13),
#  ('__', 13),
#  ('.?', 12),
#  ('여대', 12),
#  ('졸업', 12),
#  ('기대', 12),
#  ('급하', 12),
#  ('복', 12),
#  ('정', 12),
#  ('kh', 12),
#  ('허리', 12),
#  ('진', 12),
#  ('비번', 12),
#  ('하나', 12),
#  ('://', 12),
#  ('쌍둥이', 12),
#  ('in', 12),
#  ('채널', 12),
#  ('다음날', 12),
#  ('추천', 12),
#  ('자동', 12),
#  ('다른', 12),
#  ('얘기', 12),
#  ('ㅅ', 12),
#  ('참', 12),
#  ('dk', 12),
#  ('casino', 12),
#  ('추', 12),
#  ('새로', 12),
#  ('첨', 12),
#  ('오랜만', 12),
#  ('바나나', 12),
#  ('가지', 12),
#  ('+*%', 12),
#  ('kbl', 12),
#  ('바', 12),
#  ('4', 12),
#  ('왜', 12),
#  ('kc', 12),
#  ('P', 12),
#  ('리뉴얼', 12),
#  ('dd', 12),
#  ('자극', 12),
#  ('섹파', 12),
#  ('금일', 12),
#  ('콤', 12),
#  ('핑크', 12),
#  ('전문가', 12),
#  ('sl', 12),
#  ('놓', 12),
#  ('서로', 12),
#  ('괜찮', 12),
#  ('마감', 12),
#  ('통하', 12),
#  ('아름답', 11),
#  ('마넌', 11),
#  ('풀', 11),
#  ('ca', 11),
#  ('채우', 11),
#  ('dh', 11),
#  ('핸드폰', 11),
#  ('쏘', 11),
#  ('김', 11),
#  ('선', 11),
#  ('우', 11),
#  ('code', 11),
#  ('지수', 11),
#  ('df', 11),
#  ('흐르', 11),
#  ('대학교', 11),
#  ('이사', 11),
#  ('8', 11),
#  ('영', 11),
#  ('금요일', 11),
#  ('상품권', 11),
#  ('ko.fm', 11),
#  ('총', 11),
#  ('진짜', 11),
#  ('rq', 11),
#  ('관심', 11),
#  ('모르', 11),
#  ('니', 11),
#  ('베', 11),
#  ('부', 11),
#  ('hn', 11),
#  ('제재', 11),
#  ('계획', 11),
#  ('모습', 11),
#  ('모두', 11),
#  ('센치', 11),
#  ('주인', 11),
#  ('https://buly.kr/', 11),
#  ('high', 11),
#  ('주의', 11),
#  ('부근', 11),
#  ('uy', 11),
#  ('제공', 11),
#  ('토', 11),
#  ('포', 11),
#  ('공', 11),
#  ('체위', 11),
#  ('유', 11),
#  ('끼', 11),
#  ('대학생', 11),
#  ('느끼', 11),
#  ('또', 11),
#  ('메', 11),
#  ('미치', 11),
#  ('#', 11),
#  ('일품', 11),
#  ('ch', 11),
#  ('xh', 11),
#  ('프리미엄', 10),
#  ('희', 10),
#  ('~~', 10),
#  ('학교', 10),
#  ('sw', 10),
#  ('이제', 10),
#  ('ㄱ', 10),
#  ('tv', 10),
#  ('톡', 10),
#  ('슬', 10),
#  ('게임', 10),
#  ('계정', 10),
#  ('신세계', 10),
#  ('할인', 10),
#  ('https', 10),
#  ('드림', 10),
#  ('항공', 10),
#  ('능', 10),
#  ('초대', 10),
#  ('olo', 10),
#  ('젊', 10),
#  ('매칭', 10),
#  ('hy', 10),
#  ('검스', 10),
#  ('둘', 10),
#  ('yw', 10),
#  ('자매', 10),
#  ('지은', 10),
#  ('yh', 10),
#  ('박을수이또여', 10),
#  ('어떤', 10),
#  ('활동', 10),
#  ('vs', 10),
#  ('업체', 10),
#  ('맘', 10),
#  ('소녀', 10),
#  ('댄스', 10),
#  ('은주', 10),
#  ('!?', 10),
#  ('바꾸', 10),
#  ('현재', 10),
#  ('뜨겁', 10),
#  ('채영', 10),
#  ('teiegram', 10),
#  ('치', 10),
#  ('기회', 10),
#  ('제한', 10),
#  ('돌', 10),
#  ('혹시', 10),
#  ('바람', 10),
#  ('kw', 10),
#  ('체험', 10),
#  ('uw', 10),
#  ('알리', 10),
#  ('사이트', 10),
#  ('스포츠', 10),
#  ('스타일', 10),
#  ('신입', 10),
#  ('잠금', 10),
#  ('남기', 10),
#  ('돕', 10),
#  ('영화', 10),
#  ('밥', 10),
#  ('아', 10),
#  ('예정', 10),
#  ('xy', 10),
#  ('50', 10),
#  ('메시지', 10),
#  ('뿌리', 10),
#  ('솔로', 10),
#  ('alie.kr', 10),
#  ('수령', 10),
#  ('면', 9),
#  ('gk', 9),
#  ('mini', 9),
#  ('소개', 9),
#  ('정말', 9),
#  ('항상', 9),
#  ('늘', 9),
#  ('이미', 9),
#  ('실습', 9),
#  ('오르', 9),
#  ('빵', 9),
#  ('분위기', 9),
#  ('st', 9),
#  ('xb', 9),
#  ('신화', 9),
#  ('아주', 9),
#  ('fd', 9),
#  ('민정', 9),
#  ('ㅋ', 9),
#  ('벤', 9),
#  ('대상', 9),
#  ('무', 9),
#  ('gt', 9),
#  ('전액', 9),
#  ('환', 9),
#  ('미', 9),
#  ('재학', 9),
#  ('출석', 9),
#  ('담', 9),
#  ('무슨', 9),
#  ('all', 9),
#  ('벗', 9),
#  ('승무원', 9),
#  ('다혜', 9),
#  ('ht', 9),
#  ('현', 9),
#  ('@klbet', 9),
#  ('해외', 9),
#  ('북', 9),
#  ('함', 9),
#  ('사귀', 9),
#  ('ak', 9),
#  ('수신', 9),
#  ('내용', 9),
#  ('기분', 9),
#  ('민', 9),
#  ('주식', 9),
#  ('연결', 9),
#  ('통화', 9),
#  ('수빈', 9),
#  ('쉽', 9),
#  ('피부', 9),
#  ('구', 9),
#  ('++', 9),
#  ('칠', 9),
#  ('ds', 9),
#  ('트레이너', 9),
#  ('피', 9),
#  ('가장', 9),
#  ('ax', 9),
#  ('미진이', 9),
#  ('하세요', 9),
#  ('??????', 9),
#  ('%+', 9),
#  ('구경', 9),
#  ('눈', 9),
#  ('lo', 9),
#  ('.???', 9),
#  ('볼', 9),
#  ('마이', 9),
#  ('콛', 9),
#  ('te', 9),
#  ('외국인', 9),
#  ('꺼', 9),
#  ('dy', 9),
#  ('해', 9),
#  ('찾아오', 9),
#  ('쎄', 9),
#  ('삼', 9),
#  ('fg', 9),
#  ('aces', 9),
#  ('yi', 8),
#  ('이미지', 8),
#  ('40', 8),
#  ('call', 8),
#  ('1:1', 8),
#  ('초', 8),
#  ('잇', 8),
#  ('교제', 8),
#  ('프로', 8),
#  ('vvo.la', 8),
#  ('방법', 8),
#  ('월요일', 8),
#  ('음악', 8),
#  ('로얄', 8),
#  ('yd', 8),
#  ('존예녀', 8),
#  ('복권', 8),
#  ('료', 8),
#  ('신청', 8),
#  ('제휴', 8),
#  ('평생', 8),
#  ('미용사', 8),
#  ('이화여대', 8),
#  ('ws', 8),
#  ('어리', 8),
#  ('kq', 8),
#  ('온몸', 8),
#  ('쌔끈', 8),
#  (';', 8),
#  ('죵목', 8),
#  ('nn', 8),
#  ('예상', 8),
#  ('모', 8),
#  ('$', 8),
#  ('기', 8),
#  ('캐나다', 8),
#  ('무한', 8),
#  ('야동', 8),
#  ('레이스', 8),
#  ('mg', 8),
#  ('후까시', 8),
#  ('은채', 8),
#  ('팀장', 8),
#  ('쿱', 8),
#  ('여성분', 8),
#  ('gh', 8),
#  ('ooo', 8),
#  ('마무리', 8),
#  ('오만', 8),
#  ('체', 8),
#  ('개월', 8),
#  ('배민', 8),
#  ('인증', 8),
#  ('깊', 8),
#  ('nh', 8),
#  ('감정', 8),
#  ('실시간', 8),
#  ('손', 8),
#  ('구매', 8),
#  ('VIP', 8),
#  ('han.gl', 8),
#  ('노콘', 8),
#  ('필수', 8),
#  ('리그', 8),
#  ('맞', 8),
#  ('money', 8),
#  ('환영', 8),
#  ('수요일', 8),
#  ('녀', 8),
#  ('남친', 8),
#  ('일요일', 8),
#  ('누적', 8),
#  ('업계', 8),
#  ('쪽지', 8),
#  ('rt', 8),
#  ('추억', 8),
#  ('시청', 8),
#  ('푸', 8),
#  ('답변', 8),
#  ('서울', 8),
#  ('갖', 8),
#  ('작', 8),
#  ('대박', 8),
#  ('로그인', 8),
#  ('지키', 8),
#  ('페이', 8),
#  ('본사', 8),
#  ('흥미', 8),
#  ('라이트닝', 8),
#  ('hg', 8),
#  ('팔', 8),
#  ('ky', 7),
#  ('애무', 7),
#  ('전신', 7),
#  ('dx', 7),
#  ('날씨', 7),
#  ('토너', 7),
#  ('케어', 7),
#  ('미니', 7),
#  ('지나', 7),
#  ('en', 7),
#  ('도', 7),
#  ('겨울', 7),
#  ('me', 7),
#  ('켜', 7),
#  ('네이버', 7),
#  ('밴드', 7),
#  ('ll', 7),
#  ('밖', 7),
#  ('hz', 7),
#  ('쿠', 7),
#  ('쳣', 7),
#  ('트', 7),
#  ('다가오', 7),
#  ('수량', 7),
#  ('sc', 7),
#  ('nv', 7),
#  ('동행', 7),
#  ('판', 7),
#  ('학년', 7),
#  ('후배', 7),
#  ('간호', 7),
#  ('학과', 7),
#  ('다정', 7),
#  ('약속', 7),
#  ('느낌', 7),
#  ('배정', 7),
#  ('화끈', 7),
#  ('범퍼카', 7),
#  ('쟤', 7),
#  ('of', 7),
#  ('시도', 7),
#  ('www.bit.ly', 7),
#  ('홈', 7),
#  ('딥스', 7),
#  ('동', 7),
#  ('스릴', 7),
#  ('깁티', 7),
#  ('딜도', 7),
#  ('최소', 7),
#  ('이웃', 7),
#  ('터치', 7),
#  ('새해', 7),
#  ('국내', 7),
#  ('신속', 7),
#  ('hd', 7),
#  ('수수료', 7),
#  ('꼴리', 7),
#  ('못하', 7),
#  ('딥쓰롯', 7),
#  ...]
